# %% [markdown]
# ## Machine Learning Proyect Break II
#
# ##### Tema

# %%
import pandas as pd

df = pd.read_csv("./Spotify.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
# ...

# %%
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df.tail()
# Out:
#         valence  year  acousticness  \
# 170648    0.608  2020       0.08460
# 170649    0.734  2020       0.20600
# 170650    0.637  2020       0.10100
# 170651    0.195  2020       0.00998
# 170652    0.642  2020       0.13200
#
#                                                   artists  danceability  \
# 170648  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 170649                                       ['Ashnikko']         0.717
# 170650                                        ['MAMAMOO']         0.634
# 170651                                         ['Eminem']         0.671
# 170652                              ['KEVVO', 'J Balvin']         0.856
#
#         duration_ms  energy  explicit                      id  \
# 170648       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 170649       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# ...

# %% [markdown]
# 6. Data World (Spotify Music Data)
# Data World es una plataforma de datasets públicos donde se pueden encontrar datos de una amplia gama de áreas, incluidas la música, la economía, el deporte y otros. Uno de los datasets interesantes es el de Spotify Music Data.
#
# Dataset: Spotify Music Data
#
# Descripción: Este conjunto de datos contiene información sobre más de 10,000 canciones de Spotify. Cada canción tiene varias características que incluyen el tempo, energía, acústica, valencia, loudness (volumen), y popularidad. Estos atributos son útiles para tareas de análisis musical y sistemas de recomendación. El dataset es perfecto para proyectos de predicción y análisis en el ámbito musical.
# Posibles Tareas:
# Predicción de popularidad de canciones: Dado un conjunto de características musicales (como el tempo, energía, etc.), predecir cuán popular será una canción en la plataforma.
# Sistemas de recomendación: Utilizar las características acústicas para recomendar canciones similares a los usuarios, basándose en sus preferencias musicales.
# Clasificación de géneros musicales: Clasificar las canciones en diferentes géneros (por ejemplo, pop, rock, jazz) según sus características.
# Análisis de tendencias musicales: Analizar cómo cambian las características de las canciones a lo largo del tiempo o dentro de diferentes géneros.
# Tamaño: 10,000 registros.
# Este tamaño es adecuado para trabajar en proyectos de Machine Learning, como clasificación y regresión, sin que sea necesario un manejo excesivo de datos.
# Tipo de Predicción:
# Regresión: Puedes predecir un valor continuo, como la popularidad de la canción, que podría estar representado por el número de reproducciones o una escala de popularidad.
# Clasificación: Puedes clasificar las canciones en diferentes géneros musicales (por ejemplo, "pop", "rock", "electrónica") basándote en sus características acústicas.
# Sistemas de Recomendación: Este dataset también se puede usar para crear un sistema de recomendación basado en contenido, utilizando técnicas como KNN (K-Nearest Neighbors) o Filtrado Colaborativo.
# Aplicaciones de Machine Learning:
#
# Modelos supervisados:
# Regresión: Usando Árboles de Decisión, Random Forest, o Redes Neuronales para predecir la popularidad de las canciones en función de sus características acústicas.
# Clasificación: Usando modelos como SVM, Random Forest, o KNN para clasificar las canciones en géneros musicales.
# Recomendadores:
# Filtrado basado en contenido: Crear un sistema que recomienda canciones similares en función de sus características acústicas.
# Filtrado colaborativo: Combina datos de usuarios y canciones para recomendar canciones populares a usuarios con gustos similares.
# Enlace al Dataset:
#
# Puedes acceder al conjunto de datos en Spotify Music Data en Data World.
# Recomendaciones:
#
# Este dataset es una excelente opción para proyectos relacionados con música, análisis acústico, sistemas de recomendación y predicción de popularidad. Puedes explorar el uso de diferentes modelos de Machine Learning, como redes neuronales, KNN, Random Forest, etc., dependiendo de la tarea específica que decidas abordar.
